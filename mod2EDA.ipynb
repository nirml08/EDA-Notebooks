# %% [markdown]
# # EDA: Exploratory data analysis
#
# Exploratory Data Analysis (EDA) is crucial in data analysis projects! It acts as a detective, unveiling hidden patterns and relationships in the data. EDA helps in understanding the distribution and trends, acting like a compass guiding us through the data. It plays the role of a broom, cleaning the data by identifying missing values and errors. Like a puzzle solver, EDA helps select relevant features. It's a traffic signal, guiding data preparation decisions.

# %% [markdown]
# EDA is an artist, visualizing data to communicate insights effectively. It fosters collaboration, encouraging discussions among team members. As a 🛠 toolbox, it assists in model selection. EDA serves as a risk assessment tool, identifying potential challenges. Ultimately, it's a lightbulb, generating valuable insights and driving data-driven decision-making. In summary, EDA is the cornerstone of successful data analysis, leading to remarkable discoveries and data-driven decisions!

# %% [markdown]
# data_link:https://drive.google.com/file/d/13pCKXi7EAbXUWTwvi6xWYS9V2AfsCQHK/view

# %% [markdown]
# # Importing basic libraries

# %%
# basic libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/automobile.csv')

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # Domain Analysis

# %% [markdown]
# Here is information on what these columns represent.
#
# symboling: -3, -2, -1, 0, 1, 2, 3
#
# normalized-losses: Refers to the average loss payment per insured vehicle year. It is a measure of how much an insurance company pays out for claims for a particular make and model of car, adjusted for the number of vehicles insured.
#
# make: alfa-romero, audi, bmw, chevrolet, dodge, honda, isuzu, jaguar, mazda, mercedes-benz, mercury, mitsubishi, nissan, peugot, plymouth, porsche, renault, saab, subaru, toyota, volkswagen, volvo
#
# fuel-type: diesel, gas
#
# aspiration: std, turbo
#
# num-of-doors: four, two
#
# body-style: hardtop, wagon, sedan, hatchback, convertible
#
# drive-wheels: 4wd, fwd, rwd
#
# engine-location: front, rear
#
# wheel-base: continuous from 86.6 to 120.9
#
# length: continuous from 141.1 to 208.1
#
# width: continuous from 60.3 to 72.3
#
# height: continuous from 47.8 to 59.8
#
# curb-weight: continuous from 1488 to 4066
#
# engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor
#
# num-of-cylinders: eight, five, four, six, three, twelve, two
#
# engine-size: continuous from 61 to 326
#
# fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi
#
# bore: continuous from 2.54 to 3.94
#
# stroke: continuous from 2.07 to 4.17
#
# compression-ratio: continuous from 7 to 23
#
# horsepower: continuous from 48 to 288
#
# peak-rpm: continuous from 4150 to 6600
#
# city-mpg: continuous from 13 to 49
#
# highway-mpg: continuous from 16 to 54
#
# price: continuous from 5118 to 45400

# %% [markdown]
# # Basic checks

# %%
# shape
data.shape
# Out:
# (205, 26)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
num_data=data.select_dtypes(include=['int64','float64'])
num_data.columns
# Out:
# Index(['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight',
#        'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg'],
#       dtype='object')

# %%
cat_data=data.select_dtypes(include='object')
cat_data.columns
# Out:
# Index(['normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'engine-type',
#        'num-of-cylinders', 'fuel-system', 'bore', 'stroke', 'horsepower',
#        'peak-rpm', 'price'],
#       dtype='object')

# %%
#dtype
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
data.describe(include=['object'])
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                205     205       205        205          205        205
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  41      32       185        168          114         96
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system  \
# count           205             205         205              205         205
# unique            3               2           7                7           8
# top             fwd           front         ohc             four        mpfi
# freq            120             202         148              159          94
#
#         bore stroke horsepower peak-rpm price
# count    205    205        205      205   205
# unique    39     37         60       24   187
# top     3.62    3.4         68     5500     ?
# ...

# %% [markdown]
# # Handling Missing values

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# There are no missing values but there are some question marks which need to be handled
# replace ? with np.nan
data.replace('?',np.nan,inplace=True)

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
#  normalized-losses ,num-of-doors , bore , stroke , horsepower , peak-rpm,price

# %%
# price
data['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
# dtype of price
data['price'].dtype
# since price values are integer but its datatype is object(wrong data type)
# Out:
# dtype('O')

# %%
#
plt.figure(figsize=(3,3))
sns.histplot(data['normalized-losses'].astype('float64'),bins=10)
# Out:
# <Axes: xlabel='normalized-losses', ylabel='Count'>

# %%
# clearly price distribution is skewed so will go with median
data['price'].median()
# Out:
# 10295.0

# %%
data['price'].fillna(data['price'].median(),inplace=True)

# %% [markdown]
# # peak-rpm

# %%
data['peak-rpm']
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak-rpm, Length: 205, dtype: object

# %%
data['peak-rpm'].dtype
# Out:
# dtype('O')

# %%
# since values within peak-rpm is integer but given object data type(wrong)
plt.figure(figsize=(3,3))
sns.histplot(data['peak-rpm'].astype('float64'),bins=10)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='Count'>

# %%
# replace with median since distribution is skewed
data['peak-rpm'].median()
# Out:
# 5200.0

# %%
data['peak-rpm'].fillna(data['peak-rpm'].median(),inplace=True)

# %%
# bore , stroke and horsepower
data['bore'].fillna(data['bore'].median(),inplace=True)
data['stroke'].fillna(data['stroke'].median(),inplace=True)
data['horsepower'].fillna(data['horsepower'].median(),inplace=True)
data['normalized-losses'].fillna(data['normalized-losses'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# no of doors
data['num-of-doors']
# Out:
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
#        ...
# 200    four
# 201    four
# 202    four
# 203    four
# 204    four
# Name: num-of-doors, Length: 205, dtype: object

# %%
data['num-of-doors'].dtype
# Out:
# dtype('O')

# %%
# mode
data['num-of-doors'].mode()
# Out:
# 0    four
# Name: num-of-doors, dtype: object

# %%
data['num-of-doors'].fillna('four',inplace=True)

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# # Type conversion

# %% [markdown]
# # clearly there are some columns representing wrong data type
# 'normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price'

# %%
data[['normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']]=data[['normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']].astype('float64')

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratort data Analysis
# * Univariate:histogram ,countplot , boxplot
# * Bivariate : bar , line , scatter , pie , box/violin
# * Multivariate: Pairplot , heat map

# %% [markdown]
# # Hints
# Univariate
# * Histogram : 1 numerical col---> to check distribution:Normal/skewed
# * Count plot : 1 Categorical column ---> To check count of categories/value_count
# * Box plot : 1 numerical column ---> Used to check outliers
# --------------------
# Bivariate
# * Line : 1 numerical , 1 date column ---> ANalyse changes over period of time
# * scatter plot: 2 numerical cols ---> find relationship between two variable
# * bar plot: 1 numerical and categorical ---> analyse categories with numerical data
# * pie chart : 1 num , 1 cat ----> proportion of whole
# * Box plot/violin : 1 numerical and 1 categorical ---> compare distributions
# -------------------
# Multivariate
# * pairplot : numerical data---> scatter plot for all numerical cols
# * Heatmap : numerical data ----> correlation plot
